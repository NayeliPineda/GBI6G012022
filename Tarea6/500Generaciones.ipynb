# %% [markdown]
# # # Tarea6
# **Nombre:** Nayeli Pineda
#
# - Crear el modulo que se llame poblacionmendeliana.
# - Guardar las 3 funciones de: i) generacion de la poblacion, ii) conteo de frecuencia de alelos y iii) reproduccion de la poblacion en el modulo del poblacionmendeliana.
# - Generar una explicación para cada función.
# - Generar las poblaciones 500 generaciones.
# - Calcular las proporciones de AA, Aa, aA, aa de todas las generaciones

# %%
import Poblacionmendeliana as popmendel

# %%
import scipy

# %%
help(popmendel.build_population)
# Out:
# Help on function build_population in module Poblacionmendeliana:
#
# build_population(N, p)
#     "
#     build_population es una función que genera una población. La población está formada por N individuos.
#     Cada individuo tiene dos cromosomas, que contienen el alelo "A" o "a", con probabilidad p o 1-p, respectivamente.
#     La población es una lista de tuplas.

# %%
help(popmendel.compute_frequencies)
# Out:
# Help on function compute_frequencies in module Poblacionmendeliana:
#
# compute_frequencies(population)
#     compute_frequencies es una función que va a producir un recuento de genotipos para la población.
#     Como resultado, devuelve un diccionario de frecuencias genotípicas.

# %%
help(popmendel.reproduce_population)
# Out:
# Help on function reproduce_population in module Poblacionmendeliana:
#
# reproduce_population(population)
#     reproduce_population es una función que produce una nueva generación de la población mediante la reproducción.
#     Para cada uno de los N nuevos descendientes.
#     - elige a los padres al azar;
#     - la descendencia recibe un cromosoma procedente
#     cada uno de los padres.

# %%
# ?popmendel.build_population

# %%
Signature: popmendel.build_population(N, p)
Docstring:
"
build_population es una función que genera una población. La población está formada por N individuos. 
Cada individuo tiene dos cromosomas, que contienen el alelo "A" o "a", con probabilidad p o 1-p, respectivamente.
La población es una lista de tuplas. 
File:      c:\users\naye\documents\gbi6g01\popmendeliana\poblacionmendeliana.py
Type:      function

# %%
# ?popmendel.compute_frequencies

# %%
Signature: popmendel.compute_frequencies(population)
Docstring:
compute_frequencies es una función que va a producir un recuento de genotipos para la población.
Como resultado, devuelve un diccionario de frecuencias genotípicas.
File:      c:\users\naye\documents\gbi6g01\popmendeliana\poblacionmendeliana.py
Type:      function

# %%
# ?popmendel.reproduce_population

# %%
Signature: popmendel.reproduce_population(population)
Docstring:
reproduce_population es una función que produce una nueva generación de la población mediante la reproducción.
Para cada uno de los N nuevos descendientes.
- elige a los padres al azar;
- la descendencia recibe un cromosoma procedente
cada uno de los padres.
File:      c:\users\naye\documents\gbi6g01\popmendeliana\poblacionmendeliana.py
Type:      function

# %%
popmendel.build_population(N = 75, p = 0.6)
# Out:
# [('a', 'A'),
#  ('A', 'a'),
#  ('a', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('a', 'A'),
#  ('A', 'a'),
#  ('a', 'A'),
#  ('a', 'a'),
#  ('A', 'a'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'a'),
#  ('A', 'a'),
#  ('A', 'a'),
#  ('A', 'a'),
#  ('A', 'A'),
#  ('a', 'A'),
#  ('A', 'a'),
#  ('a', 'A'),
#  ('a', 'a'),
#  ('a', 'a'),
#  ('A', 'A'),
#  ('A', 'a'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('a', 'a'),
#  ('a', 'A'),
#  ('A', 'a'),
#  ('a', 'A'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('A', 'a'),
#  ('a', 'a'),
#  ('A', 'a'),
#  ('a', 'A'),
#  ('A', 'A'),
#  ('a', 'a'),
#  ('a', 'A'),
#  ('A', 'a'),
#  ('A', 'A'),
#  ('A', 'A'),
#  ('a', 'A'),
#  ('A', 'A'),
#  ('a', 'A'),
#  ('a', 'a'),
#  ('a', 'A'),
#  ('A', 'a'),
#  ('A', 'A'),
#  ('A', 'a'),
#  ('a', 'a'),
#  ('a', 'A'),
#  ('a', 'A'),
#  ('a', 'A'),
#  ('A', 'A'),
#  ('a', 'A'),
#  ('a', 'A'),
#  ('a', 'A'),
#  ('A', 'A'),
#  ('A', 'a'),
#  ('a', 'A'),
#  ('A', 'A'),
#  ('a', 'A'),
#  ('A', 'a'),
#  ('A', 'a'),
# ...

# %%
my_pop = popmendel.build_population(75, 0.4)

# %%
popmendel.compute_frequencies(my_pop)
# Out:
# Generacion 1: {'AA': 13, 'aa': 23, 'Aa': 20, 'aA': 19}
# Generacion  1 : {'AA': 12, 'aa': 28, 'Aa': 10, 'aA': 25}
# Generacion  2 : {'AA': 14, 'aa': 25, 'Aa': 16, 'aA': 20}
# Generacion  3 : {'AA': 11, 'aa': 27, 'Aa': 13, 'aA': 24}
# Generacion  4 : {'AA': 6, 'aa': 33, 'Aa': 23, 'aA': 13}
# Generacion  5 : {'AA': 5, 'aa': 29, 'Aa': 20, 'aA': 21}
# Generacion  6 : {'AA': 7, 'aa': 34, 'Aa': 19, 'aA': 15}
# Generacion  7 : {'AA': 10, 'aa': 41, 'Aa': 14, 'aA': 10}
# Generacion  8 : {'AA': 11, 'aa': 34, 'Aa': 12, 'aA': 18}
# Generacion  9 : {'AA': 10, 'aa': 29, 'Aa': 19, 'aA': 17}
# Generacion  10 : {'AA': 9, 'aa': 25, 'Aa': 16, 'aA': 25}
# Generacion  11 : {'AA': 8, 'aa': 38, 'Aa': 14, 'aA': 15}
# Generacion  12 : {'AA': 3, 'aa': 33, 'Aa': 20, 'aA': 19}
# Generacion  13 : {'AA': 6, 'aa': 40, 'Aa': 11, 'aA': 18}
# Generacion  14 : {'AA': 4, 'aa': 47, 'Aa': 13, 'aA': 11}
# Generacion  15 : {'AA': 3, 'aa': 52, 'Aa': 8, 'aA': 12}
# Generacion  16 : {'AA': 3, 'aa': 47, 'Aa': 10, 'aA': 15}
# ...
